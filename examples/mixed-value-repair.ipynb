# %% [markdown]
# # Mixed value repair example

# %% [markdown]
# This notebook will walk through how to use the `EmbeddingFeaturizer` to perform mixed value repair (i.e. when there are both numerical and categorical columns).

# %%
import sys
sys.path.append('../')

import holoclean
from detect import *
from repair.featurize import *

# %% [markdown]
# ## 1. Setup a HoloClean session.

# %%
hc = holoclean.HoloClean(
    db_name='holo',
    domain_thresh_1=0.0,
    domain_thresh_2=0.0,
    max_domain=10000,
    cor_strength=0.6,
    weight_decay=0.,
    learning_rate=0.001,
    threads=1,
    batch_size=1,
    verbose=True,
    timeout=3 * 60000,
).session
# Out:
# 11:49:48 - [DEBUG] - initiating session with parameters: {'db_user': 'holocleanuser', 'db_pwd': 'abcd1234', 'db_host': 'localhost', 'db_name': 'holo', 'threads': 1, 'timeout': 180000, 'seed': 45, 'layer_sizes': [1], 'learning_rate': 0.001, 'optimizer': 'adam', 'epochs': 20, 'weight_decay': 0.0, 'momentum': 0.0, 'batch_size': 1, 'weak_label_thresh': 0.9, 'domain_thresh_1': 0.0, 'domain_thresh_2': 0.0, 'max_domain': 10000, 'cor_strength': 0.6, 'nb_cor_strength': 0.3, 'feature_norm': False, 'weight_norm': False, 'estimator_type': 'NaiveBayes', 'estimator_epochs': 10, 'estimator_batch_size': 32, 'estimator_embedding_size': 10, 'train_attrs': None, 'infer_mode': 'dk', 'verbose': True, 'bias': False, 'print_fw': False, 'debug_mode': False}

# %% [markdown]
# ## 2. Load training data and denial constraints

# %% [markdown]
# We load the hospital dataset where there are two numerical columns: Sample and Score.
#
# We specify which attributes are numerical.

# %%
hc.load_data('hospital', '../testdata/hospital/hospital_numerical.csv',
            numerical_attrs=['Score', 'Sample'])
hc.load_dcs('../testdata/hospital/hospital_constraints.txt')
hc.ds.set_constraints(hc.get_dcs())
# Out:
# 11:53:28 - [WARNING] - Dropping the following null column from the dataset: 'Address2'
# 11:53:28 - [WARNING] - Dropping the following null column from the dataset: 'Address3'
# 11:53:30 - [ INFO] - Loaded 1000 rows with 18000 cells
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [DEBUG] - Time to create index: 0.00 secs
# 11:53:30 - [ INFO] - DONE Loading hospital_numerical.csv
# 11:53:30 - [DEBUG] - Time to load dataset: 0.38 secs
# 11:53:30 - [DEBUG] - OPENED constraints file successfully
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.Condition,t2.Condition)&EQ(t1.MeasureName,t2.MeasureName)&IQ(t1.HospitalType,t2.HospitalType)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.Condition,t2.Condition)&EQ(t1.MeasureName,t2.MeasureName)&IQ(t1.HospitalType,t2.HospitalType)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.Condition,t2.Condition)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureName,t2.MeasureName)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalType,t2.HospitalType)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.ZipCode,t2.ZipCode)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.ZipCode,t2.ZipCode)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.ZipCode,t2.ZipCode)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.PhoneNumber,t2.PhoneNumber)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.PhoneNumber,t2.PhoneNumber)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.PhoneNumber,t2.PhoneNumber)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&IQ(t1.MeasureName,t2.MeasureName)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&IQ(t1.MeasureName,t2.MeasureName)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.MeasureName,t2.MeasureName)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&IQ(t1.Stateavg,t2.Stateavg)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&IQ(t1.Stateavg,t2.Stateavg)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.Stateavg,t2.Stateavg)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.HospitalName,t2.HospitalName)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ProviderNumber,t2.ProviderNumber)&IQ(t1.HospitalName,t2.HospitalName)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.ProviderNumber,t2.ProviderNumber)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalName,t2.HospitalName)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&IQ(t1.Condition,t2.Condition)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureCode,t2.MeasureCode)&IQ(t1.Condition,t2.Condition)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureCode,t2.MeasureCode)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.Condition,t2.Condition)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.Address1,t2.Address1)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.Address1,t2.Address1)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.Address1,t2.Address1)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.HospitalOwner,t2.HospitalOwner)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.HospitalOwner,t2.HospitalOwner)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.HospitalOwner,t2.HospitalOwner)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.ProviderNumber,t2.ProviderNumber)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.ProviderNumber,t2.ProviderNumber)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.ProviderNumber,t2.ProviderNumber)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&EQ(t1.PhoneNumber,t2.PhoneNumber)&EQ(t1.HospitalOwner,t2.HospitalOwner)&IQ(t1.State,t2.State)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&EQ(t1.PhoneNumber,t2.PhoneNumber)&EQ(t1.HospitalOwner,t2.HospitalOwner)&IQ(t1.State,t2.State)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.PhoneNumber,t2.PhoneNumber)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalOwner,t2.HospitalOwner)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.State,t2.State)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.City,t2.City)&IQ(t1.CountyName,t2.CountyName)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.City,t2.City)&IQ(t1.CountyName,t2.CountyName)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.City,t2.City)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.CountyName,t2.CountyName)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.EmergencyService,t2.EmergencyService)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ZipCode,t2.ZipCode)&IQ(t1.EmergencyService,t2.EmergencyService)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.ZipCode,t2.ZipCode)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.EmergencyService,t2.EmergencyService)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.City,t2.City)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.HospitalName,t2.HospitalName)&IQ(t1.City,t2.City)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.HospitalName,t2.HospitalName)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.City,t2.City)
# 11:53:30 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&IQ(t1.MeasureCode,t2.MeasureCode)
# 11:53:30 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.MeasureName,t2.MeasureName)&IQ(t1.MeasureCode,t2.MeasureCode)
# 11:53:30 - [DEBUG] - DONE parsing predicate: EQ(t1.MeasureName,t2.MeasureName)
# 11:53:30 - [DEBUG] - DONE parsing predicate: IQ(t1.MeasureCode,t2.MeasureCode)
# 11:53:30 - [ INFO] - DONE Loading DCs from hospital_constraints.txt
# 11:53:30 - [DEBUG] - Time to load dirty data: 0.16 secs

# %% [markdown]
# ## 3. Detect erroneous cells using these two detectors.

# %%
detectors = [NullDetector(), ViolationDetector()]
hc.detect_errors(detectors)
# Out:
# 11:54:17 - [DEBUG] - DONE with Error Detector: NullDetector in 0.08 secs
# 11:54:17 - [DEBUG] - Preparing to execute 15 queries.
# 11:54:17 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."Condition"=t2."Condition" AND t1."MeasureName"=t2."MeasureName" AND t1."HospitalType"<>t2."HospitalType" AND t1."Condition"!='_nan_' AND t1."MeasureName"!='_nan_' AND t1."HospitalType"!='_nan_' AND t2."Condition"!='_nan_' AND t2."MeasureName"!='_nan_' AND t2."HospitalType"!='_nan_') with id 0
# 11:54:18 - [DEBUG] - Time to execute query with id 0: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."HospitalName"=t2."HospitalName" AND t1."ZipCode"<>t2."ZipCode" AND t1."HospitalName"!='_nan_' AND t1."ZipCode"!='_nan_' AND t2."HospitalName"!='_nan_' AND t2."ZipCode"!='_nan_') with id 1
# 11:54:18 - [DEBUG] - Time to execute query with id 1: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."HospitalName"=t2."HospitalName" AND t1."PhoneNumber"<>t2."PhoneNumber" AND t1."HospitalName"!='_nan_' AND t1."PhoneNumber"!='_nan_' AND t2."HospitalName"!='_nan_' AND t2."PhoneNumber"!='_nan_') with id 2
# 11:54:18 - [DEBUG] - Time to execute query with id 2: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."MeasureCode"=t2."MeasureCode" AND t1."MeasureName"<>t2."MeasureName" AND t1."MeasureCode"!='_nan_' AND t1."MeasureName"!='_nan_' AND t2."MeasureCode"!='_nan_' AND t2."MeasureName"!='_nan_') with id 3
# 11:54:18 - [DEBUG] - Time to execute query with id 3: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."MeasureCode"=t2."MeasureCode" AND t1."Stateavg"<>t2."Stateavg" AND t1."MeasureCode"!='_nan_' AND t1."Stateavg"!='_nan_' AND t2."MeasureCode"!='_nan_' AND t2."Stateavg"!='_nan_') with id 4
# 11:54:18 - [DEBUG] - Time to execute query with id 4: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."ProviderNumber"=t2."ProviderNumber" AND t1."HospitalName"<>t2."HospitalName" AND t1."ProviderNumber"!='_nan_' AND t1."HospitalName"!='_nan_' AND t2."ProviderNumber"!='_nan_' AND t2."HospitalName"!='_nan_') with id 5
# 11:54:18 - [DEBUG] - Time to execute query with id 5: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."MeasureCode"=t2."MeasureCode" AND t1."Condition"<>t2."Condition" AND t1."MeasureCode"!='_nan_' AND t1."Condition"!='_nan_' AND t2."MeasureCode"!='_nan_' AND t2."Condition"!='_nan_') with id 6
# 11:54:18 - [DEBUG] - Time to execute query with id 6: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."HospitalName"=t2."HospitalName" AND t1."Address1"<>t2."Address1" AND t1."HospitalName"!='_nan_' AND t1."Address1"!='_nan_' AND t2."HospitalName"!='_nan_' AND t2."Address1"!='_nan_') with id 7
# 11:54:18 - [DEBUG] - Time to execute query with id 7: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."HospitalName"=t2."HospitalName" AND t1."HospitalOwner"<>t2."HospitalOwner" AND t1."HospitalName"!='_nan_' AND t1."HospitalOwner"!='_nan_' AND t2."HospitalName"!='_nan_' AND t2."HospitalOwner"!='_nan_') with id 8
# 11:54:18 - [DEBUG] - Time to execute query with id 8: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."HospitalName"=t2."HospitalName" AND t1."ProviderNumber"<>t2."ProviderNumber" AND t1."HospitalName"!='_nan_' AND t1."ProviderNumber"!='_nan_' AND t2."HospitalName"!='_nan_' AND t2."ProviderNumber"!='_nan_') with id 9
# 11:54:18 - [DEBUG] - Time to execute query with id 9: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."HospitalName"=t2."HospitalName" AND t1."PhoneNumber"=t2."PhoneNumber" AND t1."HospitalOwner"=t2."HospitalOwner" AND t1."State"<>t2."State" AND t1."HospitalName"!='_nan_' AND t1."PhoneNumber"!='_nan_' AND t1."HospitalOwner"!='_nan_' AND t1."State"!='_nan_' AND t2."HospitalName"!='_nan_' AND t2."PhoneNumber"!='_nan_' AND t2."HospitalOwner"!='_nan_' AND t2."State"!='_nan_') with id 10
# 11:54:18 - [DEBUG] - Time to execute query with id 10: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."City"=t2."City" AND t1."CountyName"<>t2."CountyName" AND t1."City"!='_nan_' AND t1."CountyName"!='_nan_' AND t2."City"!='_nan_' AND t2."CountyName"!='_nan_') with id 11
# 11:54:18 - [DEBUG] - Time to execute query with id 11: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."ZipCode"=t2."ZipCode" AND t1."EmergencyService"<>t2."EmergencyService" AND t1."ZipCode"!='_nan_' AND t1."EmergencyService"!='_nan_' AND t2."ZipCode"!='_nan_' AND t2."EmergencyService"!='_nan_') with id 12
# 11:54:18 - [DEBUG] - Time to execute query with id 12: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."HospitalName"=t2."HospitalName" AND t1."City"<>t2."City" AND t1."HospitalName"!='_nan_' AND t1."City"!='_nan_' AND t2."HospitalName"!='_nan_' AND t2."City"!='_nan_') with id 13
# 11:54:18 - [DEBUG] - Time to execute query with id 13: 0.00 secs
# 11:54:18 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "hospital" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "hospital" as t2 WHERE t1."MeasureName"=t2."MeasureName" AND t1."MeasureCode"<>t2."MeasureCode" AND t1."MeasureName"!='_nan_' AND t1."MeasureCode"!='_nan_' AND t2."MeasureName"!='_nan_' AND t2."MeasureCode"!='_nan_') with id 14
# 11:54:18 - [DEBUG] - Time to execute query with id 14: 0.17 secs
# 11:54:18 - [DEBUG] - Time to execute 15 queries: 0.27 secs
# 11:54:18 - [DEBUG] - DONE with Error Detector: ViolationDetector in 0.38 secs
# 11:54:19 - [ INFO] - detected 11294 potentially erroneous cells
# 11:54:21 - [DEBUG] - Time to create index: 0.00 secs
# 11:54:21 - [ INFO] - DONE with error detection.
# 11:54:21 - [DEBUG] - Time to detect errors: 1.65 secs

# %% [markdown]
# ## 4. Quantize numerical columns to generate a better domain (optional)

# %% [markdown]
# Generating domains requires computing co-occurrence statistics between columns. For numerical columns, co-occurrence is not well defined, thus we can choose to quantize the column to allow for better domain generation using co-occurrence statistics.

# %%
# Quantize each of Score and Sample into 50 bins.
_ = hc.quantize_numericals([(50, ['Score']), (50, ['Sample'])])
# Out:
# 11:56:24 - [ INFO] - DONE with quantization
# 11:56:24 - [DEBUG] - Time to quantize the dataset: 0.41 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to create index: 0.00 secs
# 11:56:25 - [DEBUG] - Time to load quantized dataset: 0.99 secs

# %% [markdown]
# ## 5. Generate the domain.

# %%
hc.generate_domain()
# Out:
# 11:57:32 - [DEBUG] - Computing correlations...
# 11:57:36 - [DEBUG] - correlations:
# attr              ProviderNumber  HospitalName  Address1      City     State  \
# cond_attr
# Address1                0.973058      0.977819  1.000000  0.968957  0.926332
# City                    0.927848      0.932173  0.927911  1.000000  0.928117
# Condition               0.149259      0.141563  0.156809  0.185834  0.835806
# CountyName              0.881920      0.885445  0.882335  0.923666  0.924064
# EmergencyService        0.205623      0.202773  0.214343  0.243758  0.832506
# HospitalName            0.973002      1.000000  0.972486  0.968905  0.929428
# HospitalOwner           0.537764      0.537251  0.541772  0.548234  0.864220
# HospitalType            0.119127      0.115310  0.129153  0.157915  0.832457
# MeasureCode             0.174872      0.166578  0.185173  0.214309  0.851806
# MeasureName             0.183367      0.175159  0.193562  0.220290  0.861953
# PhoneNumber             0.973098      0.977334  0.973110  0.969938  0.933865
# ProviderNumber          1.000000      0.976860  0.971605  0.967993  0.929376
# Sample                  0.359467      0.354015  0.361244  0.369162  0.875393
# Score                   0.312788      0.316285  0.317851  0.329753  0.853992
# State                   0.131298      0.126712  0.139378  0.171034  1.000000
# Stateavg                0.195620      0.187535  0.205663  0.233962  0.923974
# ZipCode                 0.965245      0.969974  0.963988  0.968123  0.926632
#
# attr               ZipCode  CountyName  PhoneNumber  HospitalType  \
# cond_attr
# Address1          0.972127    0.963397     0.971019      0.952788
# City              0.934637    0.964278     0.926514      0.949144
# Condition         0.151838    0.207498     0.150585      0.931511
# CountyName        0.888086    1.000000     0.878957      0.945261
# EmergencyService  0.211298    0.267143     0.208070      0.920743
# HospitalName      0.972968    0.963229     0.969914      0.952904
# HospitalOwner     0.536578    0.544639     0.539034      0.931281
# HospitalType      0.123045    0.177380     0.119986      1.000000
# MeasureCode       0.178994    0.236304     0.180124      0.945956
# MeasureName       0.187517    0.245150     0.188566      0.950756
# PhoneNumber       0.972139    0.962650     1.000000      0.949689
# ProviderNumber    0.972026    0.962638     0.969544      0.951406
# Sample            0.357459    0.383294     0.360479      0.941414
# Score             0.322374    0.344383     0.315091      0.946768
# State             0.134450    0.191860     0.134547      0.919316
# Stateavg          0.200136    0.257290     0.200741      0.946051
# ZipCode           1.000000    0.962290     0.961852      0.951262
#
# attr              HospitalOwner  EmergencyService  Condition  MeasureCode  \
# cond_attr
# Address1               0.966570          0.940956   0.584203     0.236052
# City                   0.928028          0.934725   0.581284     0.233349
# Condition              0.427182          0.694642   1.000000     0.516145
# CountyName             0.883687          0.933401   0.580194     0.232055
# EmergencyService       0.439513          1.000000   0.526531     0.167806
# HospitalName           0.966538          0.941898   0.581706     0.229725
# HospitalOwner          1.000000          0.762871   0.551022     0.189318
# HospitalType           0.407650          0.689176   0.531880     0.170839
# MeasureCode            0.441436          0.718517   0.956365     1.000000
# MeasureName            0.448612          0.720594   0.957862     0.968230
# PhoneNumber            0.969216          0.942204   0.585397     0.238129
# ProviderNumber         0.966533          0.939524   0.585867     0.234108
# Sample                 0.506488          0.745238   0.643343     0.390392
# Score                  0.471779          0.754224   0.562571     0.346597
# State                  0.411698          0.687171   0.523886     0.160434
# Stateavg               0.452124          0.719776   0.957926     0.969366
# ZipCode                0.958044          0.942821   0.583916     0.234038
#
# attr              MeasureName     Score    Sample  Stateavg
# cond_attr
# Address1             0.267261  0.479344  0.418536  0.291977
# City                 0.262083  0.461002  0.398507  0.288384
# Condition            0.528375  0.296198  0.246655  0.532157
# CountyName           0.263570  0.444220  0.385469  0.288009
# EmergencyService     0.193962  0.264057  0.165028  0.208635
# HospitalName         0.261192  0.480236  0.417397  0.286113
# HospitalOwner        0.219387  0.317418  0.231994  0.236233
# HospitalType         0.198937  0.253875  0.156587  0.210978
# MeasureCode          0.960792  0.444047  0.383490  0.950992
# MeasureName          1.000000  0.448490  0.389795  0.952193
# PhoneNumber          0.269253  0.481446  0.424252  0.293902
# ProviderNumber       0.265397  0.478791  0.421917  0.290176
# Sample               0.409896  0.477632  1.000000  0.427525
# Score                0.373775  1.000000  0.341629  0.386813
# State                0.189378  0.248645  0.155601  0.224523
# Stateavg             0.963124  0.455885  0.400587  1.000000
# ZipCode              0.265329  0.482323  0.419898  0.290433
# 11:57:36 - [DEBUG] - summary of correlations:
# attr   ProviderNumber  HospitalName   Address1       City      State  \
# count       17.000000     17.000000  17.000000  17.000000  17.000000
# mean         0.533139      0.531929   0.537434   0.555402   0.895878
# std          0.378612      0.383028   0.374251   0.366126   0.048053
# min          0.119127      0.115310   0.129153   0.157915   0.832457
# 25%          0.183367      0.175159   0.193562   0.220290   0.853992
# 50%          0.359467      0.354015   0.361244   0.369162   0.923974
# 75%          0.965245      0.969974   0.963988   0.968123   0.928117
# max          1.000000      1.000000   1.000000   1.000000   1.000000
#
# attr     ZipCode  CountyName  PhoneNumber  HospitalType  HospitalOwner  \
# count  17.000000   17.000000    17.000000     17.000000      17.000000
# mean    0.536216    0.566672     0.533825      0.946250       0.685006
# std     0.377794    0.356470     0.375987      0.017519       0.264104
# min     0.123045    0.177380     0.119986      0.919316       0.407650
# 25%     0.187517    0.245150     0.188566      0.941414       0.441436
# 50%     0.357459    0.383294     0.360479      0.946768       0.506488
# 75%     0.972026    0.962650     0.961852      0.951262       0.966533
# max     1.000000    1.000000     1.000000      1.000000       1.000000
#
# attr   EmergencyService  Condition  MeasureCode  MeasureName      Score  \
# count         17.000000  17.000000    17.000000    17.000000  17.000000
# mean           0.827514   0.664350     0.383328     0.405395   0.441977
# std            0.118621   0.176119     0.297919     0.284616   0.169899
# min            0.687171   0.523886     0.160434     0.189378   0.248645
# 25%            0.719776   0.562571     0.229725     0.261192   0.317418
# 50%            0.762871   0.583916     0.234108     0.265397   0.455885
# 75%            0.940956   0.643343     0.390392     0.409896   0.479344
# max            1.000000   1.000000     1.000000     1.000000   1.000000
#
# attr      Sample   Stateavg
# count  17.000000  17.000000
# mean    0.373961   0.421120
# std     0.190479   0.273204
# min     0.155601   0.208635
# 25%     0.246655   0.286113
# 50%     0.389795   0.290433
# 75%     0.418536   0.427525
# max     1.000000   1.000000
# 11:57:36 - [DEBUG] - computing frequency and co-occurrence statistics from raw data...
# 11:57:36 - [DEBUG] - Collecting single/pair-wise statistics...
# 11:57:39 - [DEBUG] - DONE computing statistics in 2.92s
# 11:57:39 - [DEBUG] - preparing pruned co-occurring statistics...
# 100%|██████████| 17/17 [00:00<00:00, 184.63it/s]
# 11:57:39 - [DEBUG] - DONE with pruned co-occurring statistics in 0.08 secs
# 11:57:39 - [DEBUG] - generating initial set of un-pruned domain values...
# 100%|██████████| 1000/1000 [00:02<00:00, 425.42it/s]
# 11:57:42 - [DEBUG] - domain size stats: count    16744.000000
# mean         5.005017
# std          2.645148
# min          2.000000
# 25%          3.000000
# 50%          5.000000
# 75%          6.000000
# max         13.000000
# Name: domain_size, dtype: float64
# 11:57:42 - [DEBUG] - domain count by attr: HospitalName        1000
# State               1000
# CountyName          1000
# MeasureName         1000
# City                1000
# PhoneNumber         1000
# Address1            1000
# Stateavg            1000
# ZipCode             1000
# MeasureCode         1000
# EmergencyService    1000
# ProviderNumber      1000
# HospitalType        1000
# Condition           1000
# HospitalOwner       1000
# Sample               934
# Score                810
# Name: attribute, dtype: int64
# 11:57:42 - [DEBUG] - DONE generating initial set of domain values in 2.17s
# 11:57:46 - [DEBUG] - Time to create index: 0.00 secs
# 11:57:46 - [DEBUG] - Time to create index: 0.00 secs
# 11:57:46 - [DEBUG] - Time to create index: 0.00 secs
# 11:57:46 - [DEBUG] - Time to create table: 0.00 secs
# 11:57:46 - [DEBUG] - Time to create index: 0.00 secs
# 11:57:46 - [ INFO] - DONE with domain preparation.
# 11:57:46 - [DEBUG] - Time to generate the domain: 14.41 secs

# %% [markdown]
# ## 6. Use EmbeddingFeaturizer to repair errors

# %% [markdown]
# The `EmbeddingFeaturizer` is an autoencoder model that supports both regression for numerical columns and classification for categorical columns.
#
# It can be used as a replacement for the `OccurAttrFeaturizer` (co-occurrence featurizer).
#
# One must specify the numerical groups (usually each group contains 1 numerical attribute, but for multi-D numerical columns like latitude-longitude it may be useful to specify them as one group of 2 attributes).
#
# To use the embedding model as a standalone, simply omit all other featurizers.

# %%
featurizers = [
    EmbeddingFeaturizer(numerical_attr_groups=[['Score'], ['Sample']], epochs=20),
    ConstraintFeaturizer(),
]

hc.repair_errors(featurizers)
# Out:
# 12:38:05 - [DEBUG] - Time to execute query: 0.00 secs
# 12:38:05 - [DEBUG] - Time to execute query: 0.00 secs
# 12:38:05 - [DEBUG] - EmbeddingFeaturizer: training TupleEmbedding model since it was not used as an estimator
# 12:38:05 - [DEBUG] - EmbeddingFeaturizer: training with 20 epochs and 32 batch size
# 12:38:06 - [DEBUG] - LookupDataset: init categorical attributes: ['Address1', 'City', 'Condition', 'CountyName', 'EmergencyService', 'HospitalName', 'HospitalOwner', 'HospitalType', 'MeasureCode', 'MeasureName', 'PhoneNumber', 'ProviderNumber', 'State', 'Stateavg', 'ZipCode']
# 12:38:06 - [DEBUG] - LookupDataset: init numerical attributes: ['Sample', 'Score']
# 12:38:06 - [DEBUG] - LookupDataset: train categorical attributes: ['Address1', 'City', 'Condition', 'CountyName', 'EmergencyService', 'HospitalName', 'HospitalOwner', 'HospitalType', 'MeasureCode', 'MeasureName', 'PhoneNumber', 'ProviderNumber', 'State', 'Stateavg', 'ZipCode']
# 12:38:06 - [DEBUG] - LookupDataset: train numerical attributes: ['Sample', 'Score']
# 12:38:06 - [DEBUG] - TupleEmbedding: max domain size: (categorical) 13, (numerical) 13
# 12:38:07 - [DEBUG] - TupleEmbedding: training (lambda = 0.000000) on 16744 cells (16744 cells in total) in:
# 1) 15 categorical columns: ['Address1', 'City', 'Condition', 'CountyName', 'EmergencyService', 'HospitalName', 'HospitalOwner', 'HospitalType', 'MeasureCode', 'MeasureName', 'PhoneNumber', 'ProviderNumber', 'State', 'Stateavg', 'ZipCode']
# 2) 2 numerical columns: ['Sample', 'Score']
# 12:38:07 - [DEBUG] - TupleEmbedding: epoch 1 of 20
# 12:38:07 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:09<00:00, 54.05it/s]
# 12:38:16 - [DEBUG] - TupleEmbedding: average batch loss: 1.162892
# 12:38:16 - [DEBUG] - TupleEmbedding: epoch 2 of 20
# 12:38:16 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:09<00:00, 54.08it/s]
# 12:38:26 - [DEBUG] - TupleEmbedding: average batch loss: 0.759311
# 12:38:26 - [DEBUG] - TupleEmbedding: epoch 3 of 20
# 12:38:26 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:07<00:00, 67.29it/s]
# 12:38:34 - [DEBUG] - TupleEmbedding: average batch loss: 0.654578
# 12:38:34 - [DEBUG] - TupleEmbedding: epoch 4 of 20
# 12:38:34 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:09<00:00, 62.79it/s]
# 12:38:44 - [DEBUG] - TupleEmbedding: average batch loss: 0.586308
# 12:38:44 - [DEBUG] - TupleEmbedding: epoch 5 of 20
# 12:38:44 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:08<00:00, 60.82it/s]
# 12:38:53 - [DEBUG] - TupleEmbedding: average batch loss: 0.540171
# 12:38:53 - [DEBUG] - TupleEmbedding: epoch 6 of 20
# 12:38:53 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:08<00:00, 64.95it/s]
# 12:39:01 - [DEBUG] - TupleEmbedding: average batch loss: 0.506716
# 12:39:01 - [DEBUG] - TupleEmbedding: epoch 7 of 20
# 12:39:01 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:08<00:00, 64.58it/s]
# 12:39:09 - [DEBUG] - TupleEmbedding: average batch loss: 0.474408
# 12:39:09 - [DEBUG] - TupleEmbedding: epoch 8 of 20
# 12:39:09 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:07<00:00, 69.41it/s]
# 12:39:16 - [DEBUG] - TupleEmbedding: average batch loss: 0.447983
# 12:39:16 - [DEBUG] - TupleEmbedding: epoch 9 of 20
# 12:39:16 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:08<00:00, 64.24it/s]
# 12:39:24 - [DEBUG] - TupleEmbedding: average batch loss: 0.427018
# 12:39:24 - [DEBUG] - TupleEmbedding: epoch 10 of 20
# 12:39:24 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:07<00:00, 68.10it/s]
# 12:39:32 - [DEBUG] - TupleEmbedding: average batch loss: 0.408303
# 12:39:32 - [DEBUG] - TupleEmbedding: epoch 11 of 20
# 12:39:32 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:08<00:00, 62.50it/s]
# 12:39:41 - [DEBUG] - TupleEmbedding: average batch loss: 0.391848
# 12:39:41 - [DEBUG] - TupleEmbedding: epoch 12 of 20
# 12:39:41 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:07<00:00, 66.89it/s]
# 12:39:48 - [DEBUG] - TupleEmbedding: average batch loss: 0.378334
# 12:39:48 - [DEBUG] - TupleEmbedding: epoch 13 of 20
# 12:39:48 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:07<00:00, 66.70it/s]
# 12:39:56 - [DEBUG] - TupleEmbedding: average batch loss: 0.361935
# 12:39:56 - [DEBUG] - TupleEmbedding: epoch 14 of 20
# 12:39:56 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:10<00:00, 50.03it/s]
# 12:40:07 - [DEBUG] - TupleEmbedding: average batch loss: 0.354568
# 12:40:07 - [DEBUG] - TupleEmbedding: epoch 15 of 20
# 12:40:07 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:12<00:00, 43.70it/s]
# 12:40:20 - [DEBUG] - TupleEmbedding: average batch loss: 0.348170
# 12:40:20 - [DEBUG] - TupleEmbedding: epoch 16 of 20
# 12:40:20 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:12<00:00, 42.26it/s]
# 12:40:32 - [DEBUG] - TupleEmbedding: average batch loss: 0.323407
# 12:40:32 - [DEBUG] - TupleEmbedding: epoch 17 of 20
# 12:40:32 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:11<00:00, 45.06it/s]
# 12:40:44 - [DEBUG] - TupleEmbedding: average batch loss: 0.312350
# 12:40:44 - [DEBUG] - TupleEmbedding: epoch 18 of 20
# 12:40:44 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:11<00:00, 45.27it/s]
# 12:40:55 - [DEBUG] - TupleEmbedding: average batch loss: 0.298253
# 12:40:55 - [DEBUG] - TupleEmbedding: epoch 19 of 20
# 12:40:55 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:11<00:00, 43.77it/s]
# 12:41:07 - [DEBUG] - TupleEmbedding: average batch loss: 0.301920
# 12:41:07 - [DEBUG] - TupleEmbedding: epoch 20 of 20
# 12:41:07 - [DEBUG] - TupleEmbedding: using cosine LR scheduler with 524 steps
# 100%|██████████| 524/524 [00:12<00:00, 42.44it/s]
# 12:41:20 - [DEBUG] - TupleEmbedding: average batch loss: 0.295013
# 12:41:20 - [DEBUG] - EmbeddingFeaturizer: done training TupleEmbedding model.
# 12:41:20 - [DEBUG] - Time to execute query: 0.00 secs
# 12:41:20 - [DEBUG] - featurizing training data...
# 12:41:20 - [DEBUG] - TupleEmbedding: getting features in batches (# batches = 2, size = 10000) ...
# 100%|██████████| 2/2 [00:05<00:00,  3.30s/it]
# 12:41:26 - [DEBUG] - Preparing to execute 33 queries.
# 12:41:26 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'Condition'   AND  t1."MeasureName"=t2."MeasureName" AND t1."HospitalType"<>t2."HospitalType"   AND  t3.rv_val::TEXT = t2."Condition" GROUP BY _vid_, val_id with id 0
# 12:41:27 - [DEBUG] - Time to execute query with id 0: 0.00 secs
# 12:41:27 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'MeasureName'   AND  t1."Condition"=t2."Condition" AND t1."HospitalType"<>t2."HospitalType"   AND  t3.rv_val::TEXT = t2."MeasureName" GROUP BY _vid_, val_id with id 1
# 12:41:27 - [DEBUG] - Time to execute query with id 1: 0.00 secs
# 12:41:27 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'HospitalType'   AND  t1."Condition"=t2."Condition" AND t1."MeasureName"=t2."MeasureName"   AND  t3.rv_val::TEXT <> t2."HospitalType" GROUP BY _vid_, val_id with id 2
# 12:41:27 - [DEBUG] - Time to execute query with id 2: 0.01 secs
# 12:41:27 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'HospitalName'   AND  t1."ZipCode"<>t2."ZipCode"   AND  t3.rv_val::TEXT = t2."HospitalName" GROUP BY _vid_, val_id with id 3
# 12:41:27 - [DEBUG] - Time to execute query with id 3: 0.00 secs
# 12:41:27 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'ZipCode'   AND  t1."HospitalName"=t2."HospitalName"   AND  t3.rv_val::TEXT <> t2."ZipCode" GROUP BY _vid_, val_id with id 4
# 12:41:27 - [DEBUG] - Time to execute query with id 4: 0.00 secs
# 12:41:27 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'HospitalName'   AND  t1."PhoneNumber"<>t2."PhoneNumber"   AND  t3.rv_val::TEXT = t2."HospitalName" GROUP BY _vid_, val_id with id 5
# 12:41:27 - [DEBUG] - Time to execute query with id 5: 0.00 secs
# 12:41:27 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'PhoneNumber'   AND  t1."HospitalName"=t2."HospitalName"   AND  t3.rv_val::TEXT <> t2."PhoneNumber" GROUP BY _vid_, val_id with id 6
# 12:41:28 - [DEBUG] - Time to execute query with id 6: 0.00 secs
# 12:41:28 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'MeasureCode'   AND  t1."MeasureName"<>t2."MeasureName"   AND  t3.rv_val::TEXT = t2."MeasureCode" GROUP BY _vid_, val_id with id 7
# 12:41:28 - [DEBUG] - Time to execute query with id 7: 0.00 secs
# 12:41:28 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'MeasureName'   AND  t1."MeasureCode"=t2."MeasureCode"   AND  t3.rv_val::TEXT <> t2."MeasureName" GROUP BY _vid_, val_id with id 8
# 12:41:28 - [DEBUG] - Time to execute query with id 8: 0.01 secs
# 12:41:28 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'MeasureCode'   AND  t1."Stateavg"<>t2."Stateavg"   AND  t3.rv_val::TEXT = t2."MeasureCode" GROUP BY _vid_, val_id with id 9
# 12:41:28 - [DEBUG] - Time to execute query with id 9: 0.00 secs
# 12:41:28 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'Stateavg'   AND  t1."MeasureCode"=t2."MeasureCode"   AND  t3.rv_val::TEXT <> t2."Stateavg" GROUP BY _vid_, val_id with id 10
# 12:41:28 - [DEBUG] - Time to execute query with id 10: 0.00 secs
# 12:41:28 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'ProviderNumber'   AND  t1."HospitalName"<>t2."HospitalName"   AND  t3.rv_val::TEXT = t2."ProviderNumber" GROUP BY _vid_, val_id with id 11
# 12:41:28 - [DEBUG] - Time to execute query with id 11: 0.00 secs
# 12:41:28 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'HospitalName'   AND  t1."ProviderNumber"=t2."ProviderNumber"   AND  t3.rv_val::TEXT <> t2."HospitalName" GROUP BY _vid_, val_id with id 12
# 12:41:28 - [DEBUG] - Time to execute query with id 12: 0.00 secs
# 12:41:28 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'MeasureCode'   AND  t1."Condition"<>t2."Condition"   AND  t3.rv_val::TEXT = t2."MeasureCode" GROUP BY _vid_, val_id with id 13
# 12:41:28 - [DEBUG] - Time to execute query with id 13: 0.00 secs
# 12:41:28 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'Condition'   AND  t1."MeasureCode"=t2."MeasureCode"   AND  t3.rv_val::TEXT <> t2."Condition" GROUP BY _vid_, val_id with id 14
# 12:41:28 - [DEBUG] - Time to execute query with id 14: 0.01 secs
# 12:41:28 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'HospitalName'   AND  t1."Address1"<>t2."Address1"   AND  t3.rv_val::TEXT = t2."HospitalName" GROUP BY _vid_, val_id with id 15
# 12:41:29 - [DEBUG] - Time to execute query with id 15: 0.00 secs
# 12:41:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'Address1'   AND  t1."HospitalName"=t2."HospitalName"   AND  t3.rv_val::TEXT <> t2."Address1" GROUP BY _vid_, val_id with id 16
# 12:41:29 - [DEBUG] - Time to execute query with id 16: 0.00 secs
# 12:41:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'HospitalName'   AND  t1."HospitalOwner"<>t2."HospitalOwner"   AND  t3.rv_val::TEXT = t2."HospitalName" GROUP BY _vid_, val_id with id 17
# 12:41:29 - [DEBUG] - Time to execute query with id 17: 0.00 secs
# 12:41:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'HospitalOwner'   AND  t1."HospitalName"=t2."HospitalName"   AND  t3.rv_val::TEXT <> t2."HospitalOwner" GROUP BY _vid_, val_id with id 18
# 12:41:29 - [DEBUG] - Time to execute query with id 18: 0.00 secs
# 12:41:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'HospitalName'   AND  t1."ProviderNumber"<>t2."ProviderNumber"   AND  t3.rv_val::TEXT = t2."HospitalName" GROUP BY _vid_, val_id with id 19
# 12:41:29 - [DEBUG] - Time to execute query with id 19: 0.00 secs
# 12:41:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'ProviderNumber'   AND  t1."HospitalName"=t2."HospitalName"   AND  t3.rv_val::TEXT <> t2."ProviderNumber" GROUP BY _vid_, val_id with id 20
# 12:41:29 - [DEBUG] - Time to execute query with id 20: 0.00 secs
# 12:41:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'HospitalName'   AND  t1."PhoneNumber"=t2."PhoneNumber" AND t1."HospitalOwner"=t2."HospitalOwner" AND t1."State"<>t2."State"   AND  t3.rv_val::TEXT = t2."HospitalName" GROUP BY _vid_, val_id with id 21
# 12:41:29 - [DEBUG] - Time to execute query with id 21: 0.00 secs
# 12:41:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'PhoneNumber'   AND  t1."HospitalName"=t2."HospitalName" AND t1."HospitalOwner"=t2."HospitalOwner" AND t1."State"<>t2."State"   AND  t3.rv_val::TEXT = t2."PhoneNumber" GROUP BY _vid_, val_id with id 22
# 12:41:29 - [DEBUG] - Time to execute query with id 22: 0.00 secs
# 12:41:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'HospitalOwner'   AND  t1."HospitalName"=t2."HospitalName" AND t1."PhoneNumber"=t2."PhoneNumber" AND t1."State"<>t2."State"   AND  t3.rv_val::TEXT = t2."HospitalOwner" GROUP BY _vid_, val_id with id 23
# 12:41:29 - [DEBUG] - Time to execute query with id 23: 0.00 secs
# 12:41:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'State'   AND  t1."HospitalName"=t2."HospitalName" AND t1."PhoneNumber"=t2."PhoneNumber" AND t1."HospitalOwner"=t2."HospitalOwner"   AND  t3.rv_val::TEXT <> t2."State" GROUP BY _vid_, val_id with id 24
# 12:41:30 - [DEBUG] - Time to execute query with id 24: 0.00 secs
# 12:41:30 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'City'   AND  t1."CountyName"<>t2."CountyName"   AND  t3.rv_val::TEXT = t2."City" GROUP BY _vid_, val_id with id 25
# 12:41:30 - [DEBUG] - Time to execute query with id 25: 0.00 secs
# 12:41:30 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'CountyName'   AND  t1."City"=t2."City"   AND  t3.rv_val::TEXT <> t2."CountyName" GROUP BY _vid_, val_id with id 26
# 12:41:30 - [DEBUG] - Time to execute query with id 26: 0.00 secs
# 12:41:30 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'ZipCode'   AND  t1."EmergencyService"<>t2."EmergencyService"   AND  t3.rv_val::TEXT = t2."ZipCode" GROUP BY _vid_, val_id with id 27
# 12:41:30 - [DEBUG] - Time to execute query with id 27: 0.00 secs
# 12:41:30 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'EmergencyService'   AND  t1."ZipCode"=t2."ZipCode"   AND  t3.rv_val::TEXT <> t2."EmergencyService" GROUP BY _vid_, val_id with id 28
# 12:41:30 - [DEBUG] - Time to execute query with id 28: 0.00 secs
# 12:41:30 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'HospitalName'   AND  t1."City"<>t2."City"   AND  t3.rv_val::TEXT = t2."HospitalName" GROUP BY _vid_, val_id with id 29
# 12:41:30 - [DEBUG] - Time to execute query with id 29: 0.00 secs
# 12:41:30 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'City'   AND  t1."HospitalName"=t2."HospitalName"   AND  t3.rv_val::TEXT <> t2."City" GROUP BY _vid_, val_id with id 30
# 12:41:30 - [DEBUG] - Time to execute query with id 30: 0.00 secs
# 12:41:30 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'MeasureName'   AND  t1."MeasureCode"<>t2."MeasureCode"   AND  t3.rv_val::TEXT = t2."MeasureName" GROUP BY _vid_, val_id with id 31
# 12:41:30 - [DEBUG] - Time to execute query with id 31: 0.00 secs
# 12:41:30 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "hospital" as t1, "hospital" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'MeasureCode'   AND  t1."MeasureName"=t2."MeasureName"   AND  t3.rv_val::TEXT <> t2."MeasureCode" GROUP BY _vid_, val_id with id 32
# 12:41:30 - [DEBUG] - Time to execute query with id 32: 0.00 secs
# 12:41:30 - [DEBUG] - Time to execute 33 queries: 0.22 secs
# 12:41:32 - [DEBUG] - DONE featurization. Feature tensor size: torch.Size([16744, 13, 36])
# 12:41:32 - [DEBUG] - generating weak labels...
# 12:41:32 - [DEBUG] - Time to execute query: 0.01 secs
# 100%|██████████| 7383/7383 [00:00<00:00, 35341.22it/s]
# 12:41:32 - [DEBUG] - DONE generating weak labels.
# 12:41:32 - [DEBUG] - generating mask...
# 12:41:32 - [DEBUG] - Time to execute query: 0.02 secs
# 100%|██████████| 16744/16744 [00:00<00:00, 56525.59it/s]
# 12:41:32 - [DEBUG] - DONE generating mask.
# 12:41:32 - [ INFO] - DONE setting up featurized dataset.
# 12:41:32 - [DEBUG] - Time to featurize data: 192.78 secs
# 12:41:32 - [DEBUG] - training model with first layer size: ['torch.Size([3, 1])', 'torch.Size([33, 1])']
# 12:41:32 - [ INFO] - DONE setting up repair model.
# 12:41:32 - [DEBUG] - Time to setup repair model: 192.78 secs
# 12:41:32 - [ INFO] - training with 7383 training examples (cells)
#   0%|          | 0/20 [00:00<?, ?it/s]12:41:35 - [DEBUG] - Epoch 1, cost = 0.862056, acc = 91.10%
#   5%|▌         | 1/20 [00:03<00:57,  3.00s/it]12:41:38 - [DEBUG] - Epoch 2, cost = 0.261415, acc = 91.10%
#  10%|█         | 2/20 [00:05<00:52,  2.90s/it]12:41:40 - [DEBUG] - Epoch 3, cost = 0.225592, acc = 91.10%
#  15%|█▌        | 3/20 [00:08<00:46,  2.76s/it]12:41:43 - [DEBUG] - Epoch 4, cost = 0.219040, acc = 91.10%
#  20%|██        | 4/20 [00:10<00:42,  2.66s/it]12:41:45 - [DEBUG] - Epoch 5, cost = 0.216994, acc = 91.10%
#  25%|██▌       | 5/20 [00:12<00:39,  2.60s/it]12:41:48 - [DEBUG] - Epoch 6, cost = 0.216169, acc = 91.10%
#  30%|███       | 6/20 [00:15<00:35,  2.55s/it]12:41:50 - [DEBUG] - Epoch 7, cost = 0.215774, acc = 91.10%
#  35%|███▌      | 7/20 [00:17<00:32,  2.54s/it]12:41:53 - [DEBUG] - Epoch 8, cost = 0.215555, acc = 91.10%
#  40%|████      | 8/20 [00:20<00:30,  2.51s/it]12:41:55 - [DEBUG] - Epoch 9, cost = 0.215416, acc = 91.10%
#  45%|████▌     | 9/20 [00:22<00:27,  2.49s/it]12:41:58 - [DEBUG] - Epoch 10, cost = 0.215316, acc = 91.10%
#  50%|█████     | 10/20 [00:25<00:24,  2.48s/it]12:42:00 - [DEBUG] - Epoch 11, cost = 0.215238, acc = 91.10%
#  55%|█████▌    | 11/20 [00:27<00:22,  2.48s/it]12:42:03 - [DEBUG] - Epoch 12, cost = 0.215173, acc = 91.10%
#  60%|██████    | 12/20 [00:30<00:19,  2.46s/it]12:42:05 - [DEBUG] - Epoch 13, cost = 0.215117, acc = 91.10%
#  65%|██████▌   | 13/20 [00:32<00:17,  2.46s/it]12:42:08 - [DEBUG] - Epoch 14, cost = 0.215067, acc = 91.10%
#  70%|███████   | 14/20 [00:35<00:14,  2.49s/it]12:42:10 - [DEBUG] - Epoch 15, cost = 0.215022, acc = 91.10%
#  75%|███████▌  | 15/20 [00:37<00:12,  2.48s/it]12:42:13 - [DEBUG] - Epoch 16, cost = 0.214982, acc = 91.10%
#  80%|████████  | 16/20 [00:40<00:09,  2.48s/it]12:42:15 - [DEBUG] - Epoch 17, cost = 0.214945, acc = 91.10%
#  85%|████████▌ | 17/20 [00:42<00:07,  2.47s/it]12:42:18 - [DEBUG] - Epoch 18, cost = 0.214912, acc = 91.10%
#  90%|█████████ | 18/20 [00:45<00:05,  2.54s/it]12:42:20 - [DEBUG] - Epoch 19, cost = 0.214881, acc = 91.10%
#  95%|█████████▌| 19/20 [00:47<00:02,  2.57s/it]12:42:23 - [DEBUG] - Epoch 20, cost = 0.214853, acc = 91.10%
# 100%|██████████| 20/20 [00:50<00:00,  2.54s/it]
# 12:42:23 - [ INFO] - DONE training repair model.
# 12:42:23 - [DEBUG] - Time to fit repair model: 51.35 secs
# 12:42:23 - [ INFO] - inferring on 11038 examples (cells)
# 12:42:23 - [DEBUG] - Time to execute query: 0.10 secs
# 12:42:25 - [DEBUG] - Time to create index: 0.00 secs
# 12:42:27 - [DEBUG] - Time to create index: 0.00 secs
# 12:42:27 - [ INFO] - DONE inferring repairs.
# 12:42:27 - [DEBUG] - Time to infer correct cell values: 1.82 secs
# 12:42:27 - [DEBUG] - Time to create table: 0.00 secs
# 12:42:27 - [DEBUG] - Time to create index: 0.00 secs
# 12:42:27 - [DEBUG] - Time to create index: 0.00 secs
# 12:42:27 - [ INFO] - DONE collecting the inferred values.
# 12:42:27 - [DEBUG] - Time to collect inferred values: 0.05 secs
# 12:42:27 - [ INFO] - DONE generating repaired dataset
# 12:42:27 - [DEBUG] - Time to store repaired dataset: 0.19 secs

# %% [markdown]
# ## 7. Evaluate the correctness of the results.

# %%
report = hc.evaluate(fpath='../testdata/hospital/hospital_numerical_clean.csv',
            tid_col='tid',
            attr_col='attribute',
            val_col='correct_val')
# Out:
# 12:44:30 - [DEBUG] - Time to create index: 0.00 secs
# 12:44:30 - [DEBUG] - Time to create index: 0.00 secs
# 12:44:30 - [ INFO] - DONE Loading hospital_numerical_clean.csv
# 12:44:30 - [DEBUG] - Time to evaluate repairs: 1.00 secs
# 12:44:30 - [DEBUG] - Time to execute query: 0.00 secs
# 12:44:30 - [DEBUG] - Preparing to execute 15 queries.
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'ProviderNumber'       AND NOT t1."ProviderNumber" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 0
# 12:44:30 - [DEBUG] - Time to execute query with id 0: 0.00 secs
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'HospitalName'       AND NOT t1."HospitalName" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 1
# 12:44:30 - [DEBUG] - Time to execute query with id 1: 0.00 secs
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'Address1'       AND NOT t1."Address1" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 2
# 12:44:30 - [DEBUG] - Time to execute query with id 2: 0.00 secs
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'City'       AND NOT t1."City" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 3
# 12:44:30 - [DEBUG] - Time to execute query with id 3: 0.00 secs
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'State'       AND NOT t1."State" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 4
# 12:44:30 - [DEBUG] - Time to execute query with id 4: 0.00 secs
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'ZipCode'       AND NOT t1."ZipCode" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 5
# 12:44:30 - [DEBUG] - Time to execute query with id 5: 0.00 secs
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'CountyName'       AND NOT t1."CountyName" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 6
# 12:44:30 - [DEBUG] - Time to execute query with id 6: 0.00 secs
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'PhoneNumber'       AND NOT t1."PhoneNumber" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 7
# 12:44:30 - [DEBUG] - Time to execute query with id 7: 0.00 secs
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'HospitalType'       AND NOT t1."HospitalType" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 8
# 12:44:30 - [DEBUG] - Time to execute query with id 8: 0.00 secs
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'HospitalOwner'       AND NOT t1."HospitalOwner" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 9
# 12:44:30 - [DEBUG] - Time to execute query with id 9: 0.00 secs
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'EmergencyService'       AND NOT t1."EmergencyService" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 10
# 12:44:30 - [DEBUG] - Time to execute query with id 10: 0.00 secs
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'Condition'       AND NOT t1."Condition" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 11
# 12:44:30 - [DEBUG] - Time to execute query with id 11: 0.00 secs
# 12:44:30 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'MeasureCode'       AND NOT t1."MeasureCode" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 12
# 12:44:31 - [DEBUG] - Time to execute query with id 12: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'MeasureName'       AND NOT t1."MeasureName" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 13
# 12:44:31 - [DEBUG] - Time to execute query with id 13: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT COUNT(*) FROM   (SELECT t2._tid_, t2._attribute_, t2._value_      FROM "hospital" as t1, "hospital_clean" as t2     WHERE t1._tid_ = t2._tid_       AND t2._attribute_ = 'Stateavg'       AND NOT t1."Stateavg" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|'))) as errors, "inf_values_dom" as repairs WHERE errors._tid_ = repairs._tid_   AND errors._attribute_ = repairs.attribute   AND repairs.rv_value = ANY(string_to_array(regexp_replace(errors._value_,'[{""}]','','gi'),'|')) with id 14
# 12:44:31 - [DEBUG] - Time to execute query with id 14: 0.00 secs
# 12:44:31 - [DEBUG] - Time to execute 15 queries: 0.11 secs
# 12:44:31 - [DEBUG] - Time to execute query: 0.00 secs
# 12:44:31 - [DEBUG] - Time to execute query: 0.00 secs
# 12:44:31 - [DEBUG] - Preparing to execute 15 queries.
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'ProviderNumber'   AND NOT t1."ProviderNumber" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 0
# 12:44:31 - [DEBUG] - Time to execute query with id 0: 0.01 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'HospitalName'   AND NOT t1."HospitalName" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 1
# 12:44:31 - [DEBUG] - Time to execute query with id 1: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'Address1'   AND NOT t1."Address1" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 2
# 12:44:31 - [DEBUG] - Time to execute query with id 2: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'City'   AND NOT t1."City" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 3
# 12:44:31 - [DEBUG] - Time to execute query with id 3: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'State'   AND NOT t1."State" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 4
# 12:44:31 - [DEBUG] - Time to execute query with id 4: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'ZipCode'   AND NOT t1."ZipCode" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 5
# 12:44:31 - [DEBUG] - Time to execute query with id 5: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'CountyName'   AND NOT t1."CountyName" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 6
# 12:44:31 - [DEBUG] - Time to execute query with id 6: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'PhoneNumber'   AND NOT t1."PhoneNumber" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 7
# 12:44:31 - [DEBUG] - Time to execute query with id 7: 0.01 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'HospitalType'   AND NOT t1."HospitalType" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 8
# 12:44:31 - [DEBUG] - Time to execute query with id 8: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'HospitalOwner'   AND NOT t1."HospitalOwner" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 9
# 12:44:31 - [DEBUG] - Time to execute query with id 9: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'EmergencyService'   AND NOT t1."EmergencyService" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 10
# 12:44:31 - [DEBUG] - Time to execute query with id 10: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'Condition'   AND NOT t1."Condition" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 11
# 12:44:31 - [DEBUG] - Time to execute query with id 11: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'MeasureCode'   AND NOT t1."MeasureCode" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 12
# 12:44:31 - [DEBUG] - Time to execute query with id 12: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'MeasureName'   AND NOT t1."MeasureName" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 13
# 12:44:31 - [DEBUG] - Time to execute query with id 13: 0.00 secs
# 12:44:31 - [DEBUG] - Starting to execute query SELECT count(*) FROM  "hospital" as t1, "hospital_clean" as t2 WHERE t1._tid_ = t2._tid_   AND t2._attribute_ = 'Stateavg'   AND NOT t1."Stateavg" = ANY(string_to_array(regexp_replace(t2._value_,'[{""}]','','gi'),'|')) with id 14
# 12:44:31 - [DEBUG] - Time to execute query with id 14: 0.00 secs
# 12:44:31 - [DEBUG] - Time to execute 15 queries: 0.11 secs
# 12:44:32 - [DEBUG] - Time to execute query: 0.00 secs
# 12:44:32 - [ INFO] - Precision = 0.98, Recall = 0.92, Repairing Recall = 0.96, F1 = 0.95, Repairing F1 = 0.97, Detected Errors = 435, Total Errors = 455, Correct Repairs = 419, Total Repairs = 427, Total Repairs on correct cells (Grdth present) = 8, Total Repairs on incorrect cells (Grdth present) = 419, RMSE = 0.00
# 12:44:32 - [DEBUG] - Time to generate report: 0.27 secs

# %%
report
# Out:
# EvalReport(precision=0.9812646370023419, recall=0.9208791208791208, repair_recall=0.9632183908045977, f1=0.9501133786848073, repair_f1=0.9721577726218098, detected_errors=435.0, total_errors=455.0, correct_repairs=419.0, total_repairs=427, total_repairs_grdt=427.0, total_repairs_grdt_correct=8.0, total_repairs_grdt_incorrect=419.0, rmse=0.0)
