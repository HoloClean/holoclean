# %%
import psycopg2
import pandas as pd
from string import Template

# %%
dataname = "small_census_01"
index = "v1"

# %%
# dataname = "small_adult_1"
# index = "1"

# %%
# dataname =  "food_small"
# index = "v1"

# %% [markdown]
# ### Connect to db

# %%
conn = psycopg2.connect(host="localhost",
                        database="{}_{}".format(dataname,index), 
                        user="holocleanuser", 
                        password="abcd1234")

# %%
def query_df(q, value = []):
    if len(value) != 0:
        df = pd.read_sql_query(q, conn, params=value)
    else:
        df = pd.read_sql_query(q, conn)
    return df

# %%
def table_lists():
    df = query_df("""SELECT table_name FROM information_schema.tables
       WHERE table_schema = 'public'""")
    return df

# %%
table_lists()
# Out:
#                  table_name
# 0                  dk_cells
# 1               cell_domain
# 2                pos_values
# 3                cell_distr
# 4            inf_values_idx
# 5            inf_values_dom
# 6  small_census_01_repaired
# 7     small_census_01_clean
# 8           small_census_01

# %%
# get all attributes 
data = query_df("select * from {}".format(dataname))
attributes = data.columns.values[1:]
attributes
# Out:
# array(['age', 'class_of_worker', 'detailed_industry_recode',
#        'detailed_occupation_recode', 'education', 'wage_per_hour',
#        'enroll_in_edu_inst_last_wk', 'marital_stat',
#        'major_industry_code', 'major_occupation_code', 'race',
#        'hispanic_origin', 'sex', 'member_of_a_labor_union',
#        'reason_for_unemployment', 'full_or_part_time_employment_stat',
#        'capital_gains', 'capital_losses', 'dividends_from_stocks',
#        'tax_filer_stat', 'region_of_previous_residence',
#        'state_of_previous_residence',
#        'detailed_household_and_family_stat',
#        'detailed_household_summary_in_household', 'instance_weight',
#        'migration_code-change_in_msa', 'migration_code-change_in_reg',
#        'migration_code-move_within_reg', 'live_in_this_house_1_year_ago',
#        'migration_prev_res_in_sunbelt', 'num_persons_worked_for_employer',
#        'family_members_under_18', 'country_of_birth_father',
#        'country_of_birth_mother', 'country_of_birth_self', 'citizenship',
#        'own_business_or_self_employed', 'veterans_benefits',
#        'weeks_worked_in_year', 'year', 'income'], dtype=object)

# %% [markdown]
# ### Total Errors

# %%
errors_template = Template('SELECT t1._tid_, t2._attribute_, t1.\"$attr\" as init, t2._value_ as gt '\
                            'FROM $init_table as t1, $grdt_table as t2 '\
                            'WHERE t1._tid_ = t2._tid_ '\
                              'AND t2._attribute_ = \'$attr\' '\
                              'AND t1.\"$attr\" != t2._value_')

# %%
def get_total_errors():
    all_error = []
    for attr in attributes:
        query = errors_template.substitute(init_table=dataname, grdt_table='%s_clean'%dataname,
                        attr=attr)
        df = query_df(query)
        all_error.append(df)
    return all_error

# %%
all_error = get_total_errors()

# %%
all_error = pd.concat(all_error, ignore_index=True)

# %%
all_error
# Out:
#    _tid_                         _attribute_  \
# 0    828                                 age
# 1    674                     class_of_worker
# 2     60            detailed_industry_recode
# 3    213            detailed_industry_recode
# 4    528            detailed_industry_recode
# 5    922          detailed_occupation_recode
# 6    459                        marital_stat
# 7    286               major_occupation_code
# 8    429                                race
# 9    753                     hispanic_origin
# 10   550             member_of_a_labor_union
# 11   262             reason_for_unemployment
# 12   454             reason_for_unemployment
# 13   523             reason_for_unemployment
# 14   516   full_or_part_time_employment_stat
# 15    43                       capital_gains
# 16   368                       capital_gains
# 17    52               dividends_from_stocks
# 18   223               dividends_from_stocks
# 19   410         state_of_previous_residence
# 20   632  detailed_household_and_family_stat
# 21   705  detailed_household_and_family_stat
# 22   940        migration_code-change_in_msa
# 23   362        migration_code-change_in_reg
# 24   299      migration_code-move_within_reg
# 25   217       migration_prev_res_in_sunbelt
# 26     5     num_persons_worked_for_employer
# 27   144     num_persons_worked_for_employer
# 28   244     num_persons_worked_for_employer
# 29   527     num_persons_worked_for_employer
# 30   660             family_members_under_18
# 31   323                         citizenship
# 32   990       own_business_or_self_employed
#
#                                      init  \
# 0                                      3x
# 1                                 prxvate
# 2                                       x
# 3                                      x3
# 4                                       x
# 5                                       x
# 6              married-a f sxouse present
# 7          adm support includixg clerical
# 8                                   whxte
# 9                               all oxher
# 10                        not ix universe
# 11                  job losex - on layoff
# 12                        not in univxrse
# 13                        not in univexse
# 14               children or xrmed forces
# 15                                      x
# 16                                      x
# 17                                      x
# 18                                      x
# 19                        not in univerxe
# 20  chxld <18 never marr not in subfamily
# 21  child <18 never marr not in xubfamily
# 22                               nonmovxr
# 23                               nonxover
# 24                different staxe in west
# 25                        nxt in universe
# 26                                      x
# 27                                      x
# 28                                      x
# 29                                      x
# 30                    mother onxy present
# 31      native- born in the unxted states
# 32                                      x
#
#                                        gt
# 0                                      33
# 1                                 private
# 2                                       4
# 3                                      43
# 4                                       0
# 5                                       0
# 6              married-a f spouse present
# 7          adm support including clerical
# 8                                   white
# 9                               all other
# 10                        not in universe
# 11                  job loser - on layoff
# 12                        not in universe
# 13                        not in universe
# 14               children or armed forces
# 15                                      0
# 16                                      0
# 17                                      0
# 18                                      0
# 19                        not in universe
# 20  child <18 never marr not in subfamily
# 21  child <18 never marr not in subfamily
# 22                               nonmover
# 23                               nonmover
# 24                different state in west
# 25                        not in universe
# 26                                      0
# 27                                      0
# 28                                      0
# 29                                      4
# 30                    mother only present
# 31      native- born in the united states
# 32                                      0

# %%
vid_template = Template("SELECT * from cell_domain where attribute = \'$attr\' and _tid_ = \'$tid\'")

# %%
query_df(vid_template.substitute(attr='detailed_household_and_family_stat', tid=632))
# Out:
#    _cid_  _tid_  _vid_                           attribute  \
# 0  26566    632   9324  detailed_household_and_family_stat
#
#                                               domain  domain_size  fixed  \
# 0  child 18+ never marr not in a subfamily|||chil...            6      0
#
#    init_index                             init_value
# 0           2  chxld <18 never marr not in subfamily

# %%
init_count = all_error.shape[0]
init_count
# Out:
# 1407

# %% [markdown]
# ### Total Repair

# %%
query = "SELECT t1._tid_, t1.attribute, t1.init_value as init, t2.rv_value as repair " \
                 "FROM %s as t1, %s as t2 " \
                 "WHERE t1._tid_ = t2._tid_ " \
                   "AND t1.attribute = t2.attribute " \
                   "AND t1.init_value != t2.rv_value"\
                %('cell_domain', 'inf_values_dom')
all_repair = query_df(query)

# %%
all_repair.head()
# Out:
#    _tid_                   attribute      init         repair
# 0      3  detailed_occupation_recode         3              0
# 1      3    detailed_industry_recode        34              0
# 2      4  detailed_occupation_recode        37              0
# 3      7       country_of_birth_self  columbia  united-states
# 4      9       country_of_birth_self    mexico  united-states

# %%
total_repair_init_count = all_repair.shape[0]
total_repair_init_count
# Out:
# 854

# %%
query = "SELECT t1._tid_, t1.attribute, t1.init_value as init, t2.rv_value as repair " \
         "FROM %s as t1, %s as t2, %s as t3 " \
         "WHERE t1._tid_ = t2._tid_ " \
           "AND t1.attribute = t2.attribute " \
           "AND t1.init_value != t2.rv_value " \
           "AND t1._tid_ = t3._tid_ " \
           "AND t1.attribute = t3._attribute_"\
        %('cell_domain', 'inf_values_dom', '%s_clean'%dataname)
repair_gt = query_df(query)

# %%
repair_gt.head(15)
# Out:
#     _tid_                   attribute                 init           repair
# 0       3    detailed_industry_recode                   34                0
# 1       3  detailed_occupation_recode                    3                0
# 2       4  detailed_occupation_recode                   37                0
# 3       7       country_of_birth_self             columbia    united-states
# 4       9       country_of_birth_self               mexico    united-states
# 5      12    detailed_industry_recode                   45                0
# 6      17    detailed_industry_recode                   45                0
# 7      17  detailed_occupation_recode                   23                0
# 8      18       country_of_birth_self                 peru    united-states
# 9      19    detailed_industry_recode                   34                0
# 10     20     family_members_under_18  mother only present  not in universe
# 11     20     country_of_birth_father               mexico    united-states
# 12     23  detailed_occupation_recode                   19                0
# 13     24       country_of_birth_self               mexico    united-states
# 14     26     family_members_under_18  mother only present  not in universe

# %%
repair_gt_init_count = repair_gt.shape[0]
repair_gt_init_count
# Out:
# 854

# %% [markdown]
# ### Correct Repair

# %%
correct_repairs_template = Template('SELECT errors._tid_, errors._attribute_, '\
                            ' errors.init, errors._value_ as gt, repairs.rv_value as repair FROM'\
                            '(SELECT t2._tid_, t2._attribute_, t2._value_, t1.\"$attr\" as init '\
                             'FROM $init_table as t1, $grdt_table as t2 '\
                             'WHERE t1._tid_ = t2._tid_ '\
                               'AND t2._attribute_ = \'$attr\' '\
                               'AND t1.\"$attr\" != t2._value_ ) as errors, $inf_dom as repairs '\
                              'WHERE errors._tid_ = repairs._tid_ '\
                                'AND errors._attribute_ = repairs.attribute '\
                                'AND errors._value_ = repairs.rv_value')

# %%
def get_total_repair():
    all_rp = []
    for attr in attributes:
        query = correct_repairs_template.substitute(init_table=dataname, grdt_table='%s_clean'%dataname, 
                                            inf_dom = 'inf_values_dom', attr=attr)
        df = query_df(query)
        all_rp.append(df)
    return all_rp

# %%
all_repair_gt = get_total_repair()

# %%
all_repair_gt = pd.concat(all_repair_gt, ignore_index=True)

# %%
all_repair_gt.head(30)
# Out:
#   _tid_                 _attribute_                               init  \
# 0   528    detailed_industry_recode                                  x
# 1   922  detailed_occupation_recode                                  x
# 2   323                 citizenship  native- born in the unxted states
#
#                                   gt                             repair
# 0                                  0                                  0
# 1                                  0                                  0
# 2  native- born in the united states  native- born in the united states

# %%
all_repair_gt.shape[0]
# Out:
# 3

# %%
wrong_repairs_template = Template('SELECT errors._tid_, errors._attribute_, '\
                            ' errors.init, errors._value_ as gt, repairs.rv_value as repair FROM'\
                            '(SELECT t2._tid_, t2._attribute_, t2._value_, t1.\"$attr\" as init '\
                             'FROM $init_table as t1, $grdt_table as t2 '\
                             'WHERE t1._tid_ = t2._tid_ '\
                               'AND t2._attribute_ = \'$attr\' '\
                               'AND t1.\"$attr\" != t2._value_ ) as errors, $inf_dom as repairs '\
                              'WHERE errors._tid_ = repairs._tid_ '\
                                'AND errors._attribute_ = repairs.attribute '\
                                'AND errors._value_ <> repairs.rv_value')

# %%
def get_total_wrong_repair():
    all_rp = []
    for attr in attributes:
        query = wrong_repairs_template.substitute(init_table=dataname, grdt_table='%s_clean'%dataname, 
                                            inf_dom = 'inf_values_dom', attr=attr)
        df = query_df(query)
        all_rp.append(df)
    return all_rp

# %%
wrong_repair_gt = get_total_wrong_repair()

# %%
wrong_repair_gt = pd.concat(wrong_repair_gt, ignore_index=True)

# %%
wrong_repair_gt
# Out:
#    _tid_                         _attribute_  \
# 0     60            detailed_industry_recode
# 1    213            detailed_industry_recode
# 2    632  detailed_household_and_family_stat
# 3    705  detailed_household_and_family_stat
# 4    299      migration_code-move_within_reg
# 5    217       migration_prev_res_in_sunbelt
# 6      5     num_persons_worked_for_employer
# 7    144     num_persons_worked_for_employer
# 8    244     num_persons_worked_for_employer
# 9    527     num_persons_worked_for_employer
# 10   660             family_members_under_18
#
#                                      init  \
# 0                                       x
# 1                                      x3
# 2   chxld <18 never marr not in subfamily
# 3   child <18 never marr not in xubfamily
# 4                 different staxe in west
# 5                         nxt in universe
# 6                                       x
# 7                                       x
# 8                                       x
# 9                                       x
# 10                    mother onxy present
#
#                                        gt  \
# 0                                       4
# 1                                      43
# 2   child <18 never marr not in subfamily
# 3   child <18 never marr not in subfamily
# 4                 different state in west
# 5                         not in universe
# 6                                       0
# 7                                       0
# 8                                       0
# 9                                       4
# 10                    mother only present
#
#                                    repair
# 0                                       0
# 1                                       0
# 2   chxld <18 never marr not in subfamily
# 3   child <18 never marr not in xubfamily
# 4                 different staxe in west
# 5                         nxt in universe
# 6                                       x
# 7                                       x
# 8                                       x
# 9                                       x
# 10                        not in universe

# %% [markdown]
# ### Detected Errors

# %%
query = "SELECT t1._tid_, t1.init_value as init, t2._value_ as gt " \
        "FROM %s as t1, %s as t2, %s as t3 " \
        "WHERE t1._tid_ = t2._tid_ AND t1._cid_ = t3._cid_ " \
        "AND t1.attribute = t2._attribute_ " \
        "AND t1.init_value != t2._value_" \
        % ('cell_domain', '%s_clean'%dataname, 'dk_cells')

# %%
init_error = query_df(query)

# %%
init_error.shape[0]
# Out:
# 14

# %%
init_error.head(10)
# Out:
#    _tid_                               init                                 gt
# 0      5                                  x                                  0
# 1     60                                  x                                  4
# 2    144                                  x                                  0
# 3    213                                 x3                                 43
# 4    217                    nxt in universe                    not in universe
# 5    244                                  x                                  0
# 6    299            different staxe in west            different state in west
# 7    323  native- born in the unxted states  native- born in the united states
# 8    527                                  x                                  4
# 9    528                                  x                                  0

# %% [markdown]
# ### Feature Weights

# %%
# example: 2777
